# %%
from sqlite_utils import fetch_all
import nltk
from nltk.tokenize import word_tokenize
from nltk import WordNetLemmatizer
from nltk import wordnet as wn
from collections import Counter, defaultdict

# %%
machiavelli, montesquieu = fetch_all()

# %%
len(machiavelli)
# Out:
# 434

# %%
machiavelli[0].lower()
# Out:
# 'on the borders of this desert clime, one has told me, i will encounter the shadow of the great montesquieu. is this him who is before me?'

# %% [markdown]
# #### Processing:
#
# 1. Tokenize each sentence in lower-cased text
# 2. Lemmatize each word in each sentence (results were not satisfying, so...)
# 3. Simplify lemmas via finding most common synsets

# %%
machia_tokens = [word_tokenize(sent.lower()) for sent in machiavelli]
machia_tokens[0][:8]
# Out:
# ['on', 'the', 'borders', 'of', 'this', 'desert', 'clime', ',']

# %%
wnl = WordNetLemmatizer()
machia_lemmas = [[wnl.lemmatize(w) for w in sent] for sent in machia_tokens]
machia_lemmas[2][0:8]
# Out:
# ['is', 'this', 'the', 'philosopher', 'or', 'the', 'statesman', 'who']

# %%
def synset_lemmatizer(word):
    """
    Simplify words by taking their simpler or most common synsets. Words up to 3 letters do not get modified.
    
    Examples:
        in: "hello", out: "hello"
        in: "distanced", out: "distance"
        in: "spaces", out: "space"
        in: "told", out: "tell"
    It's not perfect:
        in: "comprehend", out: "grok"
    """
    
    # don't modify small words
    if len(word) <=3:
        return word
    
    try:
        # get synsets        
        synsets_list = wn.wordnet.synsets(word)

        # clear synsets: get names as strings
        synsets_list = [w.name().split(".")[0] for w in synsets_list]

        word_counter = Counter(synsets_list)

        # if there are many words
        if len(word_counter) > 1:
            word_freq1, word_freq2 = word_counter.most_common(2) # each is a tuple: ("word", counts)

            # if they have the same frequencies: pick the shorter word, else pick the first
            if word_freq1[1] == word_freq2[1]:
                if len(word_freq1[0]) <= len(word_freq2[0]):
                    return word_freq1[0]
                else:
                    return word_freq2[0]
            else:
                return word_freq1[0]

        # if there is only one word    
        else:
            return word_counter.most_common()[0][0]
        
    # if there are no synsets, return the word as it is
    except IndexError:
        return word

# %%
machia_lemmas2 = [[synset_lemmatizer(w) for w in sent] for sent in machia_lemmas]
machia_lemmas2[5][0:8]
# Out:
# ['this', 'is', 'what', 'deceive', 'you', ',', 'montesquieu', ',']

# %%
" ".join(machia_lemmas[0])
# Out:
# 'on the border of this desert clime , one ha told me , i will encounter the shadow of the great montesquieu . is this him who is before me ?'

# %%
" ".join(machia_lemmas2[0])
# Out:
# 'on the border of this desert climate , one ha tell me , i will meet the shadow of the great montesquieu . is this him who is ahead me ?'

# %%
machiavelli[0]
# Out:
# 'On the borders of this desert clime, one has told me, I will encounter the shadow of the great Montesquieu. Is this him who is before me?'

# %% [markdown]
# Later in the project, we might need to revert this process by de-simplifying the words. Although more methods will be explored, a word mapping that keeps track of every change made so far will probably be useful.
#
# However, as seen below, two differents words can get the same mapping (and then would get overwritten if we implemented a simple dictionary). Instead, we can use a `collections.defaultdict(list)` which solves the issue without much additional strain.

# %%
word_mappings_ = {new:old for (old, new) in zip([w for sent in machia_tokens for w in sent], 
                                     [w for sent in machia_lemmas2 for w in sent])}

len(word_mappings_) == len(Counter([w for sent in machia_tokens for w in sent]))
# Out:
# False

# %%
word_mappings = defaultdict(list)

# %%
word_mappings
# Out:
# defaultdict(list, {})

# %%
for (old, new) in zip([w for sent in machia_tokens for w in sent], 
                    [w for sent in machia_lemmas2 for w in sent]):
    
    if old not in word_mappings[new]:
        word_mappings[new].append(old)

# %%
word_mappings
# Out:
# defaultdict(list,
#             {'on': ['on'],
#              'the': ['the'],
#              'border': ['borders', 'border'],
#              'of': ['of'],
#              'this': ['this'],
#              'desert': ['desert'],
#              'climate': ['clime'],
#              ',': [','],
#              'one': ['one', 'ones', 'unity'],
#              'ha': ['has'],
#              'tell': ['told', 'tell', 'telling', 'tells'],
#              'me': ['me'],
#              'i': ['i'],
#              'will': ['will'],
#              'meet': ['encounter',
#               'meet',
#               'meetings',
#               'encounters',
#               'meeting'],
#              'shadow': ['shadow', 'shadows'],
#              'great': ['great', 'greatest', 'greater'],
#              'montesquieu': ['montesquieu'],
#              '.': ['.'],
#              'is': ['is'],
#              'him': ['him'],
#              'who': ['who'],
#              'ahead': ['before', 'ahead'],
#              '?': ['?'],
#              'among': ['among'],
#              'celebrated': ['illustrious', 'famous'],
#              'personage': ['personages'],
#              'whose': ['whose'],
#              'people': ['people', 'peoples'],
#              'sojourn': ['sojourn'],
#              'darkness': ['darkness'],
#              'there': ['there'],
#              'none': ['none'],
#              'desire': ['desire', 'desired'],
#              'to': ['to'],
#              'more': ['more'],
#              'than': ['than'],
#              'drive': ['driven', 'drive'],
#              'back': ['back', 'hinder'],
#              'into': ['into'],
#              'unknown': ['unknown'],
#              'space': ['spaces', 'space'],
#              'by': ['by'],
#              'migration': ['migration'],
#              'soul': ['souls', 'soul'],
#              'give': ['give',
#               'given',
#               'giving',
#               'gave',
#               'consecrates',
#               'devoted',
#               'devote',
#               'gives'],
#              'thanks': ['thanks'],
#              'coincidence': ['happenstance', 'coincidences'],
#              'that': ['that'],
#              'finally': ['finally'],
#              'place': ['places', 'place', 'placed', 'placing'],
#              'in': ['in'],
#              'presence': ['presence'],
#              'writer': ['author', 'writer', 'writers', 'authors'],
#              'spirit': ['spirit', 'spirits', 'spirited'],
#              'law': ['laws', 'law', 'jurisprudence'],
#              'philosopher': ['philosopher', 'philosophers'],
#              'or': ['or'],
#              'statesman': ['statesman', 'solon', 'statesmen'],
#              'talk': ['speaks', 'speaking', 'spoken', 'speak', 'spoke'],
#              'therefore': ['thus', 'therefore'],
#              'what': ['what'],
#              'importance': ['importance'],
#              'can': ['can'],
#              'death': ['death'],
#              'have': ['have', 'having'],
#              'for': ['for'],
#              'those': ['those'],
#              'live': ['lived', 'live'],
#              'through': ['through'],
#              'think': ['thought',
#               'conceived',
#               'conceive',
#               'think',
#               'thoughts',
#               'imagine',
#               'thinking'],
#              'since': ['since'],
#              'doe': ['does'],
#              'not': ['not'],
#              'die': ['die', 'died', 'perished', 'perish', 'dice'],
#              'a': ['as', 'a'],
#              'do': ['do', 'done', 'doing'],
#              'know': ['know', 'knows', 'knew', 'knowing', 'known'],
#              'adequate': ['tolerable'],
#              'condition': ['condition', 'conditions'],
#              'which': ['which'],
#              'make': ['made', 'makes', 'make', 'making'],
#              'u': ['us'],
#              'here': ['here'],
#              'until': ['until'],
#              'day': ['day', 'days'],
#              'last': ['last', 'lasted'],
#              'judgment': ['judgment', 'judgments'],
#              'be': ['be', 'were', 'been', 'being'],
#              'deliver': ['delivered', 'delivers'],
#              'from': ['from'],
#              'care': ['cares', 'care', 'tutelage', 'cared'],
#              'and': ['and'],
#              'concern': ['concerns', 'concern', 'interested'],
#              'material': ['material'],
#              'life': ['life', 'lives'],
#              'domain': ['domain', 'domains'],
#              'pure': ['pure', 'purest'],
#              'reason': ['reason', 'reasons'],
#              'converse': ['converse'],
#              'with': ['with'],
#              'men': ['men'],
#              'fill': ['filled', 'fill'],
#              'universe': ['universe'],
#              'sound': ['sound'],
#              'their': ['their'],
#              'name': ['names', 'name', 'naming', 'named'],
#              ';': [';'],
#              'follow': ['follow', 'followed', 'following', 'follows'],
#              'afar': ['afar'],
#              'revolution': ['revolutions', 'revolution'],
#              'state': ['states', 'state', 'provinces', 'province', 'stated'],
#              'fall': ['fall', 'falling', 'fallen', 'falls'],
#              'transformation': ['transformation'],
#              'empire': ['empires', 'empire'],
#              'study': ['meditate', 'meditated', 'studied', 'studies'],
#              'upon': ['upon'],
#              'new': ['new'],
#              'constitution': ['constitutions', 'constitution'],
#              'change': ['changes', 'change', 'changing', 'changed'],
#              'custom': ['customs', 'traditions', 'custom'],
#              'idea': ['ideas', 'idea'],
#              'europe': ['europe'],
#              'progress': ['progress', 'progression', 'advancement'],
#              'civilization': ['civilization', 'civilizations'],
#              'politics': ['politics'],
#              'art': ['arts', 'art'],
#              'industry': ['industry', 'industries'],
#              'sphere': ['sphere'],
#              'philosophic': ['philosophical'],
#              ':': [':'],
#              'theater': ['theatre'],
#              '!': ['!'],
#              'subject': ['subjects', 'subject'],
#              'astonishment': ['astonishment'],
#              'point': ['points', 'point', 'pointed'],
#              'view': ['view', 'views'],
#              'unheard-of': ['unheard-of'],
#              'revelation': ['revelations'],
#              'wonder': ['marvels', 'wonder'],
#              'if': ['if'],
#              'believe': ['believe', 'believed', 'believing'],
#              'derive': ['descend', 'derive'],
#              'like': ['like', 'liking'],
#              'profound': ['profound'],
#              'retirement': ['retirement'],
#              'we': ['we'],
#              'finish': ['finish', 'finishes'],
#              'receive': ['receiving', 'received', 'receive'],
#              'lesson': ['lessons'],
#              'history': ['history', 'histories'],
#              'qualification': ['qualifications'],
#              'humanity': ['humanity'],
#              'wind': ['nothingness', 'wind'],
#              'itself': ['itself'],
#              'break': ['broken', 'breaking', 'breaks', 'broke', 'break'],
#              'all': ['all'],
#              'tie': ['ties', 'tying', 'tied'],
#              'bind': ['bind'],
#              'earth': ['earth'],
#              'because': ['because'],
#              'posterity': ['posterity'],
#              'still': ['still'],
#              'you': ['you'],
#              'impart': ['imparted', 'impart'],
#              'movement': ['movements', 'movement'],
#              'human': ['human'],
#              'your': ['your'],
#              'political': ['political'],
#              'principle': ['principles', 'principle'],
#              'rule': ['rule',
#               'ruled',
#               'rules',
#               'ruling',
#               'decreeing',
#               'rulings'],
#              'at': ['at'],
#              'present': ['present', 'presents', 'presented', 'presenting'],
#              'over': ['over'],
#              'about': ['nearly', 'around', 'about', 'almost'],
#              'half': ['half'],
#              'person': ['someone', 'person'],
#              'could': ['could'],
#              'free': ['freed', 'free'],
#              'fear': ['fear', 'dreading'],
#              'effect': ['effectuating', 'effect', 'effects'],
#              'drab': ['somber'],
#              'passage': ['passage', 'passages'],
#              'lead': ['leads', 'lead', 'leading'],
#              'hell': ['hell'],
#              'eden': ['heavens'],
#              'it': ['it', 'its'],
#              'good': ['better', 'good', 'goods', 'salutary', 'best'],
#              'he': ['he'],
#              'himself': ['himself'],
#              'title': ['titles'],
#              'glory': ['glory', 'glories'],
#              'ageless': ['eternal', 'perpetual'],
#              'justice': ['justice'],
#              'grok': ['comprehend', 'apprehend'],
#              'irony': ['irony'],
#              'hide': ['hides', 'hidden', 'hide'],
#              'behind': ['behind'],
#              'word': ['words', 'word'],
#              'french': ['french'],
#              'publicist': ['publicist', 'publicists'],
#              'judge': ['judges', 'judged', 'judge'],
#              'crowd': ['crowd', 'crowds'],
#              'only': ['only'],
#              'my': ['my'],
#              'blind': ['blind'],
#              'prejudice': ['prejudice', 'prejudices'],
#              'book': ['book', 'books'],
#              'fatal': ['fatal'],
#              'reputation': ['reputation'],
#              'render': ['rendered', 'render', 'renders', 'rendering'],
#              'responsible': ['responsible'],
#              'absolutism': ['tyrannies', 'despotism', 'tyranny', 'absolutism'],
#              'attract': ['attracted', 'attract'],
#              'imprecation': ['malediction'],
#              'body': ['personified',
#               'body',
#               'bodies',
#               'personifies',
#               'personify'],
#              'hate': ['hatred', 'hatreds', 'hate'],
#              'poison': ['poisoned', 'poison'],
#              'disapproval': ['disapproval'],
#              'seem': ['seems', 'seem', 'seemed'],
#              'far': ['far', 'further'],
#              'yet': ['yet'],
#              'did': ['did'],
#              '15': ['15'],
#              'year': ['years', 'year'],
#              'serve': ['served', 'serve', 'serving'],
#              'fatherland': ['homeland'],
#              'wa': ['was'],
#              'republic': ['republic', 'republics'],
#              'conspire': ['conspired', 'conspire'],
#              'independence': ['independence'],
#              'defend': ['defended', 'defend', 'defending'],
#              'without': ['without'],
#              'reprieve': ['respite'],
#              'against': ['against'],
#              'louis': ['louis'],
#              'xii': ['xii'],
#              'spanish': ['spanish'],
#              'jules': ['jules'],
#              'ii': ['ii'],
#              'borgia': ['borgia'],
#              'would': ['would'],
#              'suffocate': ['suffocated', 'suffocate'],
#              'protect': ['protected', 'protect', 'protecting', 'protects'],
#              'bloody': ['bloody'],
#              'intrigue': ['intrigues', 'intrigue', 'machinations'],
#              'grow': ['grew', 'growing', 'grow', 'grows'],
#              'pot': ['senses'],
#              'fight': ['fighting', 'fights', 'fight', 'combat', 'fought'],
#              'delicacy': ['diplomacy'],
#              'another': ['another'],
#              'sword': ['sword', 'swords'],
#              'deal': ['dealing', 'deals', 'deal'],
#              'negociate': ['negotiating'],
#              'join': ['joining', 'joined'],
#              'thread': ['threads', 'thread'],
#              'accord': ['accordance', 'accord'],
#              "'s": ["'s"],
#              'interest': ['interests', 'interest'],
#              'then': ['then'],
#              'crush': ['crushed', 'crush'],
#              'between': ['between'],
#              'power': ['powers', 'power'],
#              'flip': ['tossed'],
#              'war': ['war', 'wars', 'warfare'],
#              'skiff': ['skiff'],
#              'an': ['an'],
#              'oppressive': ['oppressive', 'tyrannical'],
#              'autocratic': ['autocratic'],
#              'government': ['government', 'governments'],
#              'support': ['supported',
#               'support',
#               'supports',
#               'reinforcement',
#               'supporting'],
#              'firenze': ['florence'],
#              'these': ['these'],
#              'popular': ['popular'],
#              'institution': ['institutions', 'institution'],
#              'whom': ['whom'],
#              'saw': ['saw'],
#              'luck': ['fortune', 'fortunes', 'luck'],
#              'medici': ['medicis'],
#              "'": ["'"],
#              'torturer': ['torturers'],
#              'come': ['come', 'came', 'comes', 'coming'],
#              'after': ['after'],
#              'soderini': ['soderini'],
#              'promote': ['elevated', 'promoting'],
#              'along': ['along'],
#              'liberty': ['liberty', 'liberties'],
#              'yield': ['succumbed', 'yielding', 'yields', 'yield', 'yielded'],
#              'banishment': ['banishment', 'banishments'],
#              'glance': ['glance'],
#              'prince': ['prince', 'princes'],
#              'condescend': ['deigning', 'deign'],
#              'turn': ['turn', 'turns'],
#              'towards': ['towards'],
#              'poor': ['poor'],
#              'forget': ['forgotten', 'forget', 'forgot'],
#              'crime': ['crimes', 'crime'],
#              'won': ['won'],
#              'ingratitude': ['ingratitude'],
#              'party': ['party', 'parties'],
#              'possibly': ['perhaps'],
#              'just': ['just', 'simply'],
#              'diplomat': ['diplomat'],
#              'fantasy': ['fantasy'],
#              'mean': ['intended',
#               'means',
#               'intend',
#               'mean',
#               'intends',
#               'meaning',
#               'meanings',
#               'meant'],
#              'publication': ['publication', 'publications'],
#              'promotion': ['publicity'],
#              'stay': ['remained', 'remain', 'remains'],
#              'strange': ['stranger', 'strange'],
#              'under': ['under'],
#              'influence': ['influence', 'influences'],
#              'share': ['shared', 'shares', 'share'],
#              'italian': ['italian'],
#              'principality': ['principalities'],
#              'avid': ['avid'],
#              'embroider': ['aggrandize'],
#              'themselves': ['themselves'],
#              'expense': ['expense', 'expenses'],
#              'each': ['each'],
#              'other': ['other'],
#              'direct': ['directed', 'directing', 'direct', 'directs'],
#              'astute': ['astute'],
#              'most': ['most'],
#              'punic': ['perfidious', 'punic'],
#              'think_of': ['reputed'],
#              'nice': ['skillful'],
#              'deceive': ['deceives', 'deceived', 'deceiving', 'deceive'],
#              'well': ['well'],
#              'truth': ['truth', 'truths'],
#              'king': ['kings', 'king'],
#              'moral': ['moral', 'morals'],
#              'but': ['but'],
#              'such': ['such'],
#              'should': ['should'],
#              'always': ['always'],
#              'founder': ['founder', 'founders'],
#              'doctrine': ['doctrine', 'doctrines'],
#              'paternity': ['paternity'],
#              'impute': ['attributed'],
#              'heart': ['heart', 'hearts'],
#              'machiavellianism': ['machiavellianism'],
#              'machiavelli.moses': ['machiavelli.moses'],
#              'sesostris': ['sesostris'],
#              'solomon': ['solomon'],
#              'lysander': ['lysander'],
#              'philippe': ['philippe'],
#              'alexander': ['alexander'],
#              'macedon': ['macedonia'],
#              'agathocles': ['agathocles'],
#              'romulus': ['romulus'],
#              'tarquin': ['tarquin', 'tarquins'],
#              'julius': ['julius'],
#              'cesar': ['cesar'],
#              'augustus': ['augustus'],
#              'even': ['even'],
#              'nero': ['nero'],
#              'charlemagne': ['charlemagne'],
#              'theodoric': ['theodoric'],
#              'clovis': ['clovis'],
#              'hugues': ['hugues'],
#              'capet': ['capet'],
#              'xi': ['xi'],
#              'gonzalves': ['gonzalves'],
#              'cordoba': ['cordova'],
#              '--': ['--'],
#              'are': ['are'],
#              'ancestor': ['ancestors'],
#              'move': ['move', 'moved', 'moves'],
#              'course': ['course', 'courses'],
#              'list': ['list'],
#              'long': ['long', 'longer', 'longest'],
#              'learn': ['learned', 'learns'],
#              'nothing': ['nothing'],
#              'they': ['they'],
#              "n't": ["n't"],
#              'already': ['already'],
#              'practice': ['practice', 'practiced'],
#              'time': ['time', 'times', 'timing'],
#              'brilliant': ['brilliant'],
#              'court': ['homage', 'court', 'tribunals', 'courts', 'tribunal'],
#              'frederic': ['frederic'],
#              'pen': ['pen', 'pens'],
#              'hand': ['hand', 'hands'],
#              'deny': ['denied', 'deny'],
#              'his': ['his'],
#              'own': ['own'],
#              'popularity': ['popularity'],
#              'rigorously': ['rigorously'],
#              'apply': ['applied', 'applies', 'apply'],
#              'doctrines.by': ['doctrines.by'],
#              'inexplicable': ['inexplicable'],
#              'fail': ['failing', 'fail'],
#              'complain': ['complain'],
#              'write': ['wrote',
#               'writes',
#               'write',
#               'written',
#               'writings',
#               'writing'],
#              'so': ['so'],
#              'many': ['many'],
#              'reproach': ['reproach'],
#              'scientist': ['scientist'],
#              'seek': ['seeking', 'seek', 'sought'],
#              'physical': ['physical'],
#              'cause': ['causes', 'cause', 'causing'],
#              'bring': ['bring', 'brings', 'bringing', 'brought'],
#              'hurt': ['injures', 'injured'],
#              'doctor': ['physician'],
#              'report': ['describes',
#               'described',
#               'report',
#               'reporting',
#               'reports',
#               'describe',
#               'reported'],
#              'illness': ['illness'],
#              'chemist': ['chemist'],
#              'record': ['records', 'recording'],
#              'moralist': ['moralist'],
#              'paint': ['paints'],
#              'vice': ['vices'],
#              'historian': ['historian'],
#              'agreement': ['agreement'],
#              'understand': ['understood', 'understand', 'understanding'],
#              'lay': ['laid'],
#              'open': ['open'],
#              'comparison': ['comparison', 'comparisons'],
#              'too': ['too'],
#              'easy': ['easy', 'easier'],
#              'victory': ['triumph', 'victory'],
#              'socrates': ['socrates'],
#              'worry': ['worry'],
#              'sophist': ['sophist'],
#              'use': ['used',
#               'employ',
#               'use',
#               'usage',
#               'usages',
#               'using',
#               'utilize'],
#              'false': ['false'],
#              'instrument': ['instrument', 'instruments'],
#              'logomachy': ['logomachy'],
#              'cleverly': ['cleverly'],
#              'others': ['others'],
#              'school': ['school', 'schools'],
#              'mine': ['mine'],
#              'let': ['let', 'permitted'],
#              'leave': ['leave', 'left'],
#              'ourselves': ['ourselves'],
#              'how': ['how'],
#              'invent': ['formulate', 'invent', 'formulated', 'invented'],
#              'system': ['system', 'systems'],
#              'doubt': ['doubt', 'uncertainty', 'doubts'],
#              'weaken': ['weaken', 'weakens', 'weakened'],
#              'up': ['up'],
#              'deduction': ['deductions', 'deduction'],
#              'fact': ['facts', 'fact'],
#              'bad': ['bad', 'worse', 'worst'],
#              'instinct': ['instincts'],
#              'powerful': ['powerful'],
#              'man': ['man'],
#              'enthusiasm': ['enthusiasm', 'enthusiasms'],
#              'evil': ['evil', 'evils', 'iniquities', 'vicious'],
#              'force': ['force', 'forces', 'forced', 'personnel'],
#              'control': ['control', 'controlled'],
#              'stop': ['stop', 'stopped', 'stopping'],
#              'show': ['demonstrate', 'show', 'showed', 'demonstrates'],
#              'flighty': ['scatterbrained'],
#              'clique': ['coterie'],
#              'baron': ['baron'],
#              'holbach': ['holbach'],
#              'j.-j': ['j.-j'],
#              'rousseau': ['rousseau'],
#              'priest': ['priest'],
#              'diderot': ['diderot'],
#              'apostle': ['apostle'],
#              'contradict': ['contradicted'],
#              'them': ['them'],
#              'draw_a_bead_on': ['aspire', 'aspires', 'aspired'],
#              'domination': ['domination', 'supremacy'],
#              'oppressor': ['oppressor'],
#              'ready': ['ready'],
#              'sacrifice': ['sacrifice', 'sacrifices'],
#              'right': ['rights', 'right'],
#              'interests.what': ['interests.what'],
#              'restrain': ['restrains', 'restrained', 'restrain'],
#              'devour': ['devouring', 'devours'],
#              'animal': ['animals', 'sensual'],
#              'call': ['calls', 'called', 'call'],
#              'origin': ['origin', 'origins'],
#              'society': ['society', 'societies'],
#              'brutal': ['brutal'],
#              'unbridled': ['unchecked'],
#              'late': ['later'],
#              'say': ['say', 'said', 'saying', 'says'],
#              'form': ['forms', 'form', 'formed'],
#              'consult': ['consulted', 'consult', 'consulting'],
#              'source': ['sources', 'source'],
#              'everywhere': ['everywhere'],
#              'appear': ['appears', 'appear', 'appeared'],
#              'rights.political': ['rights.political'],
#              'relative': ['relative'],
#              'necessity': ['necessity', 'necessities'],
#              'dominate': ['dominates', 'dominated', 'dominate'],
#              'individuals.in': ['individuals.in'],
#              'certain': ['certain'],
#              'european': ['european'],
#              'latitude': ['latitudes', 'latitude'],
#              'incapable': ['incapable'],
#              'moderation': ['moderation'],
#              'exercise': ['exercise', 'exercising', 'exercised', 'exercises'],
#              'extend': ['extended', 'extend'],
#              'become': ['becomes', 'become', 'became'],
#              'license': ['license', 'permission'],
#              'civil': ['civil'],
#              'social': ['social'],
#              'occur': ['occurs', 'occur'],
#              'lose': ['lost'],
#              'either': ['either'],
#              'separate': ['divided',
#               'dividing',
#               'divide',
#               'separating',
#               'separate',
#               'separates'],
#              'cabal': ['factions', 'faction', 'cabals'],
#              'dismember': ['dismembered'],
#              'convulsion': ['convulsions'],
#              'division': ['divisions', 'division'],
#              'prey': ['prey'],
#              'foreigner': ['foreigners'],
#              'prefer': ['prefer'],
#              'anarchy': ['anarchy'],
#              'wrong': ['wrong', 'wrongs'],
#              'once': ['once'],
#              'appoint': ['constituted', 'constitute', 'appoint'],
#              'two': ['two'],
#              'kind': ['kinds', 'kind'],
#              'enemy': ['enemies', 'enemy'],
#              'inside': ['within', 'inside'],
#              'weapon': ['weapons'],
#              'general': ['general', 'generals'],
#              'mutually': ['reciprocally', 'mutually'],
#              'communicate': ['communicate'],
#              'battle': ['battle', 'battles', 'combating'],
#              'plan': ['plans', 'contrive', 'plan'],
#              'position': ['position', 'positions', 'perspectives'],
#              'forbid': ['prohibit',
#               'proscribe',
#               'proscribing',
#               'forbid',
#               'prohibited',
#               'prohibits'],
#              'nocturnal': ['nocturnal'],
#              'attack': ['attacks',
#               'attack',
#               'attacked',
#               'attempt',
#               'attacking'],
#              'trap': ['traps', 'trappings'],
#              'ambush': ['ambushes'],
#              'unequal': ['unequal'],
#              'number': ['numbers', 'number'],
#              'troop': ['troops'],
#              'no': ['no'],
#              'combatant': ['combatants'],
#              'laugh': ['laugh'],
#              'want': ['want', 'wants', 'wanted', 'needed'],
#              'ruse': ['artifices', 'artifice'],
#              'scheme': ['strategies', 'strategy', 'schemes'],
#              'indispensable': ['indispensable'],
#              '[': ['['],
#              'inner': ['internal'],
#              ']': [']'],
#              'agitator': ['agitators'],
#              'le': ['less', 'le'],
#              'cogency': ['rigor'],
#              'basically': ['basically', 'essentially'],
#              'same': ['same'],
#              'possible': ['possible'],
#              'violent': ['violent'],
#              'mass': ['masses', 'mass'],
#              'feel': ['feelings', 'feeling', 'feel', 'felt'],
#              'passion': ['passions', 'passion'],
#              'whether': ['whether'],
#              'management': ['management'],
#              'affair': ['affairs', 'affair', 'liaison'],
#              'confide': ['confided', 'confide'],
#              'tyrant': ['autocrat', 'despot'],
#              'oligarchy': ['oligarchy'],
#              'negotiation': ['negotiation', 'negotiations'],
#              'reform': ['reform'],
#              'successful': ['successful'],
#              'help': ['help'],
#              'combination': ['combinations'],
#              'disapprove': ['disapprove'],
#              'yourself': ['yourself'],
#              'compel': ['obligated'],
#              'france': ['france'],
#              'tax': ['tasked', 'tax', 'taxes', 'taxation'],
#              'least': ['least'],
#              'state.what': ['state.what'],
#              'puerile': ['puerile'],
#              'strike': ['struck', 'striking', 'strike', 'strikes'],
#              'morality': ['morality'],
#              'ever': ['ever'],
#              'see': ['seen', 'see', 'sees', 'regarded', 'regarding', 'seeing'],
#              'single': ['single'],
#              'conduct': ['conducts', 'conduct', 'conducting', 'conducted'],
#              'govern': ['govern', 'governing', 'governs'],
#              'private': ['private'],
#              'any': ['any', 'whatever'],
#              'when': ['when'],
#              'conquest': ['conquest'],
#              'had': ['had'],
#              'motivation': ['motivation', 'motivations'],
#              'flagitious': ['heinous'],
#              'treaty': ['treaty'],
#              'tilt': ['tilts'],
#              'balance': ['balance', 'balanced'],
#              'favor': ['favor', 'favors'],
#              'undignified': ['undignified'],
#              'fraud': ['fraud'],
#              'trespass': ['usurpation'],
#              'sovereign': ['sovereign', 'sovereigns'],
#              'act': ['act', 'acts', 'deed', 'acting', 'deeds'],
#              'merit': ['merit', 'merits'],
#              'legitimate': ['legitimate'],
#              'establish': ['founded',
#               'establish',
#               'established',
#               'instituted'],
#              'keep': ['maintain',
#               'keep',
#               'keeping',
#               'keeps',
#               'maintaining',
#               'kept'],
#              'contemporary': ['contemporary'],
#              'negation': ['negation'],
#              '(': ['('],
#              'thing': ['thing', 'things'],
#              ')': [')'],
#              'regard': ['regard'],
#              'inordinately': ['extraordinarily'],
#              'limited': ['limited'],
#              'application': ['application', 'applications'],
#              'much': ['much', 'often'],
#              'relationship': ['relationships'],
#              'nation': ['nations', 'nation'],
#              'amongst': ['amongst'],
#              'governor': ['governors'],
#              'governed.moreover': ['governed.moreover'],
#              '``': ['``'],
#              "''": ["''"],
#              'infinitely': ['infinitely'],
#              'obscure': ['vague', 'obscure'],
#              'where': ['where'],
#              'begin': ['begin', 'beginning', 'begun'],
#              'end': ['end', 'ceased', 'ended'],
#              'exist': ['exist', 'exists', 'existing'],
#              "'ll": ["'ll"],
#              'quote': ['cite', 'quote'],
#              'some': ['some'],
#              'example': ['examples', 'example'],
#              'organization': ['organization', 'organizations'],
#              'public': ['public'],
#              'turbulence': ['turbulence'],
#              'democracy': ['democracy'],
#              'powerlessness': ['powerlessness'],
#              'disorder': ['disorder'],
#              'reign': ['reigns', 'reign', 'reigning'],
#              'ruin': ['ruin', 'ruined'],
#              'precipitate': ['precipitated'],
#              'audacious': ['audacious', 'intrepid'],
#              'spring': ['springs', 'spring'],
#              'forth': ['forth'],
#              'rank': ['ranks', 'rank'],
#              'gentry': ['aristocracy'],
#              'put': ['puts', 'put', 'putting'],
#              'revise': ['revises'],
#              '20': ['20'],
#              'peace': ['peace'],
#              'country': ['country', 'countries'],
#              'pisistrates': ['pisistrates'],
#              'seize': ['seized', 'seizes', 'seize', 'seizing'],
#              'bastion': ['citadel'],
#              'prepare': ['prepared', 'prepares', 'prepare'],
#              'age': ['age', 'ages'],
#              'pericles': ['pericles'],
#              'brutus': ['brutus'],
#              'rape': ['violated', 'violates', 'violate'],
#              'monarchal': ['monarchical'],
#              'rome': ['rome'],
#              'oust': ['expelled', 'expel'],
#              'dagger-point': ['dagger-point'],
#              'nobility': ['grandeur', 'nobility'],
#              'enforce': ['imposing', 'impose', 'implementing', 'imposes'],
#              'spectacle': ['spectacle'],
#              'struggle': ['struggle'],
#              'patriarchy': ['patriarchy'],
#              'common': ['plebeians', 'common', 'commons'],
#              'vital': ['vital'],
#              'led': ['led'],
#              'dissolution': ['dissolution'],
#              'caesar': ['caesar'],
#              'violator': ['lawbreakers'],
#              'roman': ['roman', 'romans'],
#              'succeed': ['succeeded', 'succeed'],
#              'cover': ['covering', 'covered', 'cover', 'covers'],
#              'entire': ['entire'],
#              'world': ['world'],
#              'debris': ['debris'],
#              'according': ['according'],
#              'however': ['nevertheless', 'however'],
#              'reality': ['reality'],
#              'save': ['saved', 'saves', 'save', 'savings'],
#              'prolong': ['prolonged', 'prolong'],
#              'being': ['existence'],
#              'century': ['centuries', 'century'],
#              'self-': ['self-'],
#              'extract': ['extracted'],
#              'consideration': ['considerations'],
#              'arrive': ['arrives', 'arrived', 'arrive'],
#              'cure': ['cures'],
#              'cut': ['cutting', 'cut', 'cuts'],
#              'iron': ['iron'],
#              'am': ['am'],
#              'preoccupy': ['preoccupied', 'preoccupy', 'preoccupies'],
#              'useful': ['useful'],
#              'necessary': ['necessary'],
#              'take': ['take', 'taken', 'takes', 'taking', 'took'],
#              'provide': ['provide', 'provides', 'provided', 'providing'],
#              'consequence': ['consequence', 'consequences'],
#              'facts.speaking': ['facts.speaking'],
#              'abstractly': ['abstractly'],
#              'violence': ['violence'],
#              'cunning': ['cunning'],
#              'yes': ['yes'],
#              'quite': ['quite'],
#              'angels.anything': ['angels.anything'],
#              'fruit': ['fruit'],
#              'justify': ['justifies', 'justify'],
#              'now': ['now'],
#              'ask': ['ask', 'asked', 'require', 'required'],
#              'why': ['why'],
#              'republican': ['republican'],
#              'preference': ['preference', 'penchant'],
#              'absolute': ['absolute'],
#              'witness': ['witness', 'witnesses'],
#              'faithlessness': ['fickleness'],
#              'cowardice': ['cowardice'],
#              'populace': ['populace'],
#              'natural': ['innate', 'natural', 'instinctive'],
#              'taste': ['taste'],
#              'servitude': ['servitude'],
#              'incapacity': ['incapacity'],
#              'respect': ['respect', 'respected'],
#              'eye': ['eyes', 'eye'],
#              'dissolve': ['dissolves', 'dissolve'],
#              'sooner': ['sooner'],
#              'react': ['respond', 'react'],
#              'device': ['devices'],
#              'destroy': ['destroy'],
#              'never': ['never'],
#              'able': ['able'],
#              'administer': ['administrate', 'administered'],
#              'greece': ['greece'],
#              'shine': ['shone'],
#              'eclipse': ['eclipses'],
#              'emperor': ['emperors', 'emperor'],
#              'developed.can': ['developed.can'],
#              'find': ['find', 'found', 'finds', 'regained', 'finding'],
#              'modern': ['modern'],
#              'numerous': ['numerous'],
#              'first': ['first'],
#              'mind.under': ['mind.under'],
#              'spain': ['spain'],
#              'germany': ['germany'],
#              'leon': ['leon'],
#              'x': ['x'],
#              'barberousse': ['barberousse'],
#              'xiv': ['xiv'],
#              'napoleon': ['napoleon'],
#              'bumbling': ['heavy-handed'],
#              'poise': ['poised'],
#              'hilt': ['hilt'],
#              'charter': ['charters', 'charter'],
#              'states.but': ['states.but'],
#              'surprise': ['surprised', 'surprises', 'surprise', 'surprising'],
#              'convert': ['convince', 'convert'],
#              'listen': ['listens', 'listen', 'listening'],
#              'err': ['mistaken'],
#              'discourse': ['discourse', 'discourses'],
#              'serious': ['serious'],
#              'cold': ['cold'],
#              'problem': ['problems', 'problem'],
#              'encyclopedist': ['encyclopedists'],
#              'catos': ['catos'],
#              'irani': ['persian'],
#              'letter': ['letters'],
#              'saint': ['saint'],
#              'nor': ['nor'],
#              'ardent': ['fervent', 'ardent'],
#              'fan': ['devotee'],
#              'our': ['our'],
#              'base': ['immoral', 'base', 'bases', 'basing'],
#              'attach': ['attached', 'attach'],
#              'true': ['true'],
#              'god': ['god'],
#              'eighteenth': ['18th'],
#              'mute': ['mute'],
#              'respectful': ['respectful'],
#              'silence': ['silence'],
#              'legislator': ['legislator', 'legislators'],
#              'despotic': ['despotic'],
#              'virtue': ['virtue', 'virtues'],
#              'useless': ['useless'],
#              'honor': ['honor', 'honors'],
#              'dangerous': ['dangerous'],
#              'obedience': ['obedience'],
#              'raise': ['raise', 'raises', 'raised', 'invoke'],
#              'arm': ['arm', 'arms', 'arming'],
#              'moment': ['instant', 'moments', 'moment'],
#              'must': ['must'],
#              'allowance': ['allowances'],
#              'suffice': ['suffices', 'suffice'],
#              'impossible': ['impossible'],
#              'manage': ['manage'],
#              'prove': ['prove'],
#              'agree': ['agree'],
#              'step': ['step', 'steps'],
#              'very': ['very'],
#              'willingly': ['willingly'],
#              'watch': ['watch'],
#              'out': ['out'],
#              'promise': ['promise', 'promising'],
#              'preciseness': ['precision'],
#              'qualify': ['characterized'],
#              'language': ['language', 'languages'],
#              'interview': ['interview'],
#              'exaggerated': ['exaggerated'],
#              'contain': ['contained', 'contains', 'contain'],
#              'badly': ['seriously', 'badly'],
#              'claim': ['claim', 'claimed', 'exact', 'claims'],
#              'incompatible': ['incompatible'],
#              'situation': ['situation', 'situations'],
#              'something': ['something'],
#              'happen': ['happened', 'happen'],
#              '1527': ['1527'],
#              'confess': ['confess'],
#              'curious': ['curious'],
#              'hear': ['hear', 'hears'],
#              'proposition': ['proposition', 'propositions'],
#              'propose': ['propose', 'proposed', 'proposes', 'proposing'],
#              'demolish': ['demolish'],
#              'piece': ['piece', 'pieces'],
#              'beautiful': ['beautiful'],
#              'alone': ['alone'],
#              'carry': ['carried', 'carry', 'persuade', 'carrying', 'carries'],
#              'despite': ['despite'],
#              'alleged': ['so-called'],
#              'permit': ['permit', 'permits'],
#              'question': ['question', 'questioned', 'questions'],
#              'o': ['o'],
#              'middle': ['middle'],
#              'politician': ['politician', 'politicians'],
#              'barbaric': ['barbaric'],
#              'today': ['today'],
#              'grace': ['grace'],
#              '1864': ['1864'],
#              'pleasure': ['pleasure', 'pleasures'],
#              'theory': ['theories', 'theory'],
#              'benefit': ['benefits', 'benefit', 'welfare'],
#              'myself': ['myself'],
#              'admire': ['admiring', 'admire'],
#              'illusion': ['illusion', 'illusions'],
#              'hold': ['hold', 'held', 'holds'],
#              'minds.seduced': ['minds.seduced'],
#              'england': ['england'],
#              'constitutional': ['constitutional'],
#              'regimen': ['regime', 'regimes'],
#              'universal': ['universal'],
#              'panacea': ['panacea'],
#              'account': ['accounted', 'accounting', 'accounts'],
#              'irresistible': ['irresistible'],
#              'tear': ['tears', 'tear', 'torn'],
#              'old': ['old', 'oldest'],
#              'anything': ['anything'],
#              'historical': ['historical'],
#              'memory': ['memory', 'memories'],
#              'superannuate': ['superannuated'],
#              'weak': ['weak'],
#              'aristotle': ['aristotle'],
#              'three': ['three'],
#              'unities.at': ['unities.at'],
#              'examine': ['examine', 'examining'],
#              'mechanism': ['mechanism', 'mechanisms'],
#              'confine': ['confine'],
#              'department': ['department', 'departments'],
#              'third': ['third'],
#              'execute': ['executes', 'executed'],
#              'minister': ['ministers', 'minister'],
#              'fantastic': ['marvelous'],
#              'scale': ['scale'],
#              'anticipate': ['foreseen',
#               'anticipated',
#               'anticipating',
#               'anticipate',
#               'foresee'],
#              'everything': ['everything'],
#              'demur': ['except'],
#              'action': ['action', 'actions'],
#              'immobility': ['immobility'],
#              'function': ['functions', 'role', 'function', 'roles'],
#              'way': ['way', 'ways'],
#              'occasion': ['occasion'],
#              'produce': ['produced', 'produce', 'producing', 'produces'],
#              'rupture': ['rupture'],
#              'carefully': ['carefully'],
#              'forge': ['forged'],
#              'limit': ['limits', 'limit'],
#              'assign': ['assigned', 'assign'],
#              'cross': ['cross', 'crossing'],
#              'independent': ['independent'],
#              'legislative': ['legislative'],
#              'assembly': ['assembly', 'assemblies'],
#              'sovereignty': ['sovereignty'],
#              'magistracy': ['magistracy', 'magistracies'],
#              'opinion': ['opinion', 'sentiments', 'sentiment', 'opinions'],
#              'specially': ['especially'],
#              'kingdom': ['kingdom', 'kingdoms'],
#              'leader': ['leader', 'leaders'],
#              'unreservedly': ['unreservedly'],
#              'accept': ['accepts',
#               'accepting',
#               'accept',
#               'consent',
#               'accepted'],
#              'passive': ['passive', 'peaceful'],
#              'condemn': ['condemned', 'condemn', 'condemns'],
#              'secrecy': ['secrecy'],
#              'overthrow': ['overthrow', 'overthrows'],
#              'rival': ['rival'],
#              'motion': ['motion'],
#              'contrary': ['contrary'],
#              'incite': ['incited'],
#              'enterprise': ['enterprises', 'initiative', 'enterprise'],
#              'surrender': ['surrendered'],
#              'assault': ['assault', 'assaults'],
#              'launch': ['launched', 'launch'],
#              'ambition': ['ambitions', 'ambition'],
#              'arena': ['arena'],
#              'unleash': ['unleashed'],
#              'little': ['little', 'slightest'],
#              'while': ['while'],
#              'inexhaustible': ['inexhaustible'],
#              'orator': ['rhetoricians', 'orators'],
#              'transform': ['transform'],
#              'deliberatory': ['deliberatory'],
#              'oratory': ['oratory'],
#              'joust': ['jousts'],
#              'diarist': ['journalists', 'journalist'],
#              'unbridle': ['unbridled'],
#              'pamphleteer': ['pamphleteers'],
#              'every': ['every'],
#              'discredit': ['discredit', 'discredited'],
#              'wait': ['wait'],
#              'calculation': ['calculations', 'calculation'],
#              'minority': ['minorities', 'minority'],
#              'gigantic': ['gigantic'],
#              'population': ['populations', 'population'],
#              'rivet': ['riveted'],
#              'work': ['work', 'working', 'works'],
#              'poverty': ['poverty'],
#              'past': ['past'],
#              'slavery': ['slavery'],
#              'parliamentary': ['parliamentary'],
#              'fiction': ['fictions', 'fiction'],
#              'happiness': ['happiness'],
#              'short': ['short'],
#              'privileged': ['privileged'],
#              'chance': ['chance'],
#              'ancient': ['ancient'],
#              'wallow': ['triumphed'],
#              'birth': ['birth'],
#              'proletarian': ['proletarian', 'proletarians'],
#              'bent': ['bent'],
#              'overwhelm': ['overwhelmed', 'overwhelms'],
#              'weight': ['weight'],
#              'destiny': ['destiny', 'fate'],
#              'few': ['few'],
#              'create': ['created', 'create', 'creating'],
#              'everlastingly': ['eternally'],
#              'staff': ['faculty', 'faculties'],
#              'recognize': ['recognizes', 'recognized', 'recognize'],
#              'ideal': ['ideal'],
#              'enjoyment': ['enjoyment'],
#              'refuse': ['refuses', 'refuse', 'refused'],
#              'real': ['real'],
#              'bitter': ['bitter'],
#              'trust': ['trust', 'rely'],
#              'belong': ['belong', 'belonging', 'belongs'],
#              'final': ['final'],
#              'perceive': ['perceived', 'perceive', 'perceiving'],
#              'original': ['original'],
#              'purity': ['purity'],
#              'consist': ['consists', 'consist'],
#              'practically': ['practically'],
#              'equal': ['equal', 'equals'],
#              'part': ['part', 'portion', 'parts'],
#              'divers': ['diverse'],
#              'group': ['groups', 'group', 'grouping'],
#              'compose': ['composed', 'compose'],
#              'allow': ['allow', 'appropriating', 'allowed'],
#              'collaborate': ['cooperate'],
#              'activity': ['activity', 'activities'],
#              'proportion': ['proportion', 'proportionality'],
#              'aristocratic': ['aristocratic'],
#              'element': ['elements', 'element'],
#              'priority': ['priority'],
#              'democratic': ['democratic'],
#              'temperament': ['temperament'],
#              'capacity': ['capacities'],
#              'different': ['different'],
#              'class': ['classes', 'class', 'categories'],
#              'enter': ['participate', 'enter', 'enters', 'entered'],
#              'degree': ['degree'],
#              'aptitude': ['aptitude'],
#              'cognition': ['knowledge'],
#              'manumit': ['emancipate'],
#              'middle_class': ['bourgeoisie'],
#              'vote': ['vote', 'votes', 'balloting', 'voted', 'voting'],
#              'poll': ['poll'],
#              'prestige': ['prestige'],
#              'manner': ['manners', 'manner'],
#              'throne': ['throne', 'thrones'],
#              'cast': ['casts'],
#              'luster': ['splendor'],
#              'supreme': ['supreme'],
#              'worship': ['worship'],
#              'surface': ['surface'],
#              'wholly': ['completely', 'entirely'],
#              'barrier': ['barriers'],
#              'dream': ['dream', 'dreaming'],
#              ...})
